# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import datetime as dt
from datetime import datetime

# %%
base = dt.datetime(2020, 12, 27)
dati_regione = pd.read_csv("data/vaccini_fixed.csv", sep = ",")
raggruppati = dati_regione.groupby('data').sum().reset_index()
date = np.linspace(0,len(raggruppati['data'].unique()), len(raggruppati))
date = np.array([base + dt.timedelta(days = i) for i in range(len(date))]) 

fig, ax = plt.subplots()

plt.plot(date, raggruppati['prima_dose']+raggruppati['seconda_dose'], color='forestgreen')
plt.plot(date, raggruppati['seconda_dose'], color='gray')

l1 = plt.scatter(x = date[-1], y = raggruppati['prima_dose'].tail(1) + raggruppati['seconda_dose'].tail(1), color = "forestgreen", alpha = 1)

x = ax.lines[-1].get_xdata()
y = ax.lines[-1].get_ydata()
y1 = ax.lines[-2].get_ydata()

ax.fill_between(x, y, y1, color='forestgreen', alpha=0.3)
ax.fill_between(x, 0, y, color='gray', alpha=0.3)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
plt.ylim(bottom = 0)
plt.xlabel("Data", size = 12)
plt.ylabel("Vaccini", size = 12)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.title("Vaccini - Italia")
lg = plt.legend([l1], ["Tot {}: {}\nTot {}: {}".format(date[-1].strftime("%d-%h"), int(raggruppati['prima_dose'].tail(1).values[0] + raggruppati['seconda_dose'].tail(1).values[0]), 
date[-2].strftime("%d-%h"), int(raggruppati['prima_dose'].tail(2).values[0] + raggruppati['seconda_dose'].tail(2).values[0]))], 
bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')
plt.grid(alpha = 0.5)
#fig.savefig("pics/vaccini/italia.png", dpi = 100, bbox_extra_artists=(lg,), bbox_inches='tight')
#plt.close(fig)

# %%
for regione in dati_regione['regione'].unique():
    per_regioni = dati_regione.loc[dati_regione['regione'] == regione][['data','prima_dose', 'seconda_dose']]
    per_regioni = per_regioni.groupby('data').sum().reset_index()
    
    base = datetime.strptime(per_regioni['data'].iloc[0], "%Y-%m-%d")
    
    date = np.linspace(0,len(per_regioni['data'].unique()), len(per_regioni))
    date = np.array([str(per_regioni['data'][0]) + dt.timedelta(days = i) for i in range(len(date))]) 
    
    fig, ax = plt.subplots()
    plt.plot(date, per_regioni['prima_dose'] + per_regioni['seconda_dose'], color='forestgreen')
    plt.plot(date, per_regioni['seconda_dose'], color='gray')
    l1 = plt.scatter(x = per_regioni['data'].iloc[-1], y = per_regioni.tail(1), color = "#0047c3", alpha = 1,
    label = "{}: {}".format(datetime.strptime(per_regioni['data'].iloc[-2]).strftime("%d-%h"),int(per_regioni.tail(1).values[0])))
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
    plt.ylim(bottom = 0)
    plt.xlabel("Data", size = 12)
    plt.ylabel("Ricoverati", size = 12)
    plt.xticks(size = 10)
    plt.yticks(size = 10)
    plt.title("Ricoverati - {}".format(regione), size = 15)
    lg = plt.legend([l1], ["{}: {}\n{}: {}".format(per_regioni['data'].iloc[-1].strftime("%d-%h"), int(per_regioni.tail(1).values[0]), 
    per_regioni['data'].iloc[-2].strftime("%d-%h"), int(per_regioni.tail(2).values[0]))], 
    bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')
    plt.grid(alpha = 0.5)
    #fig.savefig("pics/vaccini/{}.png".format(regione.lower()), dpi = 100, bbox_extra_artists=(lg,), bbox_inches='tight')
    #plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-0b10bffabc7a> in <module>
#       6
#       7     date = np.linspace(0,len(per_regioni['data'].unique()), len(per_regioni))
# ----> 8     date = np.array([str(per_regioni['data'][0]) + dt.timedelta(days = i) for i in range(len(date))])
#       9
#      10     fig, ax = plt.subplots()
#
# <ipython-input-80-0b10bffabc7a> in <listcomp>(.0)
#       6
#       7     date = np.linspace(0,len(per_regioni['data'].unique()), len(per_regioni))
# ----> 8     date = np.array([str(per_regioni['data'][0]) + dt.timedelta(days = i) for i in range(len(date))])
#       9
#      10     fig, ax = plt.subplots()
#
# TypeError: can only concatenate str (not "datetime.timedelta") to str
